# %%
import pandas as pd
import numpy as np

# %%
completo = '/Users/nicolasraimundo/Downloads/completo_2023_2024.csv'
completo23_24 = pd.read_csv(completo)

completo23_24
# Out:
#       Rk            Player   Pos  Age   Tm   G  GS    MP   FG   FGA  ...  DRB  \
# 0      1  Precious Achiuwa  PF-C   24  TOT  74  18  21.9  3.2   6.3  ...  4.0
# 1      1  Precious Achiuwa     C   24  TOR  25   0  17.5  3.1   6.8  ...  3.4
# 2      1  Precious Achiuwa    PF   24  NYK  49  18  24.2  3.2   6.1  ...  4.3
# 3      2       Bam Adebayo     C   26  MIA  71  71  34.0  7.5  14.3  ...  8.1
# 4      3      Ochai Agbaji    SG   23  TOT  78  28  21.0  2.3   5.6  ...  1.8
# ..   ...               ...   ...  ...  ...  ..  ..   ...  ...   ...  ...  ...
# 944  210   Jaylin Williams     C   21  OKC  10   0  12.7  1.6   3.3  ...  2.8
# 945  211  Kenrich Williams    PF   29  OKC   7   0   4.6  0.3   1.1  ...  1.0
# 946  212      Delon Wright    PG   31  MIA   4   1  26.8  3.0   5.0  ...  2.5
# 947  213    Thaddeus Young    PF   35  PHO   1   0   4.0  0.0   0.0  ...  0.0
# 948  214       Ivica Zubac     C   26  LAC   6   6  32.0  7.0  11.7  ...  6.3
#
# ...

# %%
completo23_24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 949 entries, 0 to 948
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rk           949 non-null    int64
#  1   Player       949 non-null    object
#  2   Pos          949 non-null    object
#  3   Age          949 non-null    int64
#  4   Tm           949 non-null    object
#  5   G            949 non-null    int64
#  6   GS           949 non-null    int64
#  7   MP           949 non-null    float64
#  8   FG           949 non-null    float64
#  9   FGA          949 non-null    float64
#  10  FG%          949 non-null    float64
#  11  3P           949 non-null    float64
#  12  3PA          949 non-null    float64
#  13  3P%          949 non-null    float64
#  14  2P           949 non-null    float64
#  15  2PA          949 non-null    float64
#  16  2P%          949 non-null    float64
#  17  eFG%         949 non-null    float64
# ...

# %%
equipo = ['LAL']

lakers23_24 = completo23_24[completo23_24['Tm'].isin(equipo)]


lakers23_24
# Out:
#       Rk               Player Pos  Age   Tm   G  GS    MP    FG   FGA  ...  \
# 126   91      Colin Castleton   C   23  LAL  16   0   3.7   0.6   1.0  ...
# 130   95         Max Christie  SG   20  LAL  67   7  14.1   1.5   3.6  ...
# 155  116        Anthony Davis   C   30  LAL  76  76  35.5   9.4  16.9  ...
# 169  126    Spencer Dinwiddie  PG   30  LAL  28   4  24.2   2.0   5.0  ...
# 210  157           Alex Fudge  SF   20  LAL   4   0   3.5   0.3   1.5  ...
# 234  171          Harry Giles   C   25  LAL   7   0   2.7   0.1   0.9  ...
# 263  194        Rui Hachimura  PF   25  LAL  68  39  26.9   5.3   9.9  ...
# 280  211         Jaxson Hayes   C   23  LAL  70   5  12.5   1.8   2.5  ...
# 293  220          D'Moi Hodge  SG   25  LAL   7   0   5.9   0.7   2.1  ...
# 301  226  Jalen Hood-Schifino  SG   20  LAL  21   0   5.2   0.5   2.1  ...
# 325  250         LeBron James  PF   39  LAL  71  71  35.3   9.6  17.9  ...
# ...

# %%
completo2 = '/Users/nicolasraimundo/Downloads/completo_2022_2023.csv'

completo22_23 = pd.read_csv(completo2)

# %%
completo22_23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029 entries, 0 to 1028
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rk           1029 non-null   int64
#  1   Player       1029 non-null   object
#  2   Pos          1029 non-null   object
#  3   Age          1029 non-null   int64
#  4   Tm           1029 non-null   object
#  5   G            1029 non-null   int64
#  6   GS           1029 non-null   int64
#  7   MP           1029 non-null   float64
#  8   FG           1029 non-null   float64
#  9   FGA          1029 non-null   float64
#  10  FG%          1029 non-null   float64
#  11  3P           1029 non-null   float64
#  12  3PA          1029 non-null   float64
#  13  3P%          1029 non-null   float64
#  14  2P           1029 non-null   float64
#  15  2PA          1029 non-null   float64
#  16  2P%          1029 non-null   float64
#  17  eFG%         1029 non-null   float64
# ...

# %%
lakers22_23 = completo22_23[completo22_23['Tm'].isin(equipo)]


lakers22_23
# Out:
#        Rk               Player Pos  Age   Tm   G  GS    MP    FG   FGA  ...  \
# 17     14      Carmelo Anthony  PF   37  LAL  69   3  26.0   4.6  10.5  ...
# 21     18         Trevor Ariza  SF   36  LAL  24  11  19.3   1.4   4.1  ...
# 24     19        D.J. Augustin  PG   34  LAL  21   0  17.8   1.9   4.1  ...
# 46     39        Kent Bazemore  SF   32  LAL  39  14  14.0   1.2   3.6  ...
# 74     63        Avery Bradley  SG   31  LAL  62  45  22.7   2.4   5.6  ...
# 90     74   Chaundee Brown Jr.  SF   23  LAL   2   0  10.5   0.5   3.5  ...
# 137   112      Darren Collison  PG   34  LAL   3   0  12.3   0.7   2.3  ...
# 160   127        Anthony Davis   C   28  LAL  40  40  35.1   9.3  17.4  ...
# 183   146      Sekou Doumbouya  PF   21  LAL   2   0   8.0   2.5   4.0  ...
# 205   161      Wayne Ellington  SG   34  LAL  43   9  18.8   2.3   5.5  ...
# 240   180       Wenyen Gabriel  PF   24  LAL  19   5  16.4   2.6   5.1  ...
# ...

# %%
completo3= '/Users/nicolasraimundo/Downloads/completo_2021_2022.csv'

completo21_22= pd.read_csv(completo3)

# %%
completo21_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029 entries, 0 to 1028
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rk           1029 non-null   int64
#  1   Player       1029 non-null   object
#  2   Pos          1029 non-null   object
#  3   Age          1029 non-null   int64
#  4   Tm           1029 non-null   object
#  5   G            1029 non-null   int64
#  6   GS           1029 non-null   int64
#  7   MP           1029 non-null   float64
#  8   FG           1029 non-null   float64
#  9   FGA          1029 non-null   float64
#  10  FG%          1029 non-null   float64
#  11  3P           1029 non-null   float64
#  12  3PA          1029 non-null   float64
#  13  3P%          1029 non-null   float64
#  14  2P           1029 non-null   float64
#  15  2PA          1029 non-null   float64
#  16  2P%          1029 non-null   float64
#  17  eFG%         1029 non-null   float64
# ...

# %%
lakers21_22 = completo21_22[completo21_22['Tm'].isin(equipo)]

lakers21_22
# Out:
#       Rk               Player Pos  Age   Tm   G  GS    MP    FG   FGA  ...  \
# 17    14      Carmelo Anthony  PF   37  LAL  69   3  26.0   4.6  10.5  ...
# 21    18         Trevor Ariza  SF   36  LAL  24  11  19.3   1.4   4.1  ...
# 24    19        D.J. Augustin  PG   34  LAL  21   0  17.8   1.9   4.1  ...
# 46    39        Kent Bazemore  SF   32  LAL  39  14  14.0   1.2   3.6  ...
# 74    63        Avery Bradley  SG   31  LAL  62  45  22.7   2.4   5.6  ...
# 90    74   Chaundee Brown Jr.  SF   23  LAL   2   0  10.5   0.5   3.5  ...
# 137  112      Darren Collison  PG   34  LAL   3   0  12.3   0.7   2.3  ...
# 160  127        Anthony Davis   C   28  LAL  40  40  35.1   9.3  17.4  ...
# 183  146      Sekou Doumbouya  PF   21  LAL   2   0   8.0   2.5   4.0  ...
# 205  161      Wayne Ellington  SG   34  LAL  43   9  18.8   2.3   5.5  ...
# 240  180       Wenyen Gabriel  PF   24  LAL  19   5  16.4   2.6   5.1  ...
# ...

# %%
lakers_21_24 = pd.concat([lakers21_22, lakers22_23, lakers23_24], ignore_index=True)

lakers_21_24.to_csv('lakers_21_24.csv', index=False)

# %%
lakers_21_24
# Out:
#      Rk            Player Pos  Age   Tm   G  GS    MP    FG   FGA  ...  DRB  \
# 0    14   Carmelo Anthony  PF   37  LAL  69   3  26.0   4.6  10.5  ...  3.3
# 1    18      Trevor Ariza  SF   36  LAL  24  11  19.3   1.4   4.1  ...  3.0
# 2    19     D.J. Augustin  PG   34  LAL  21   0  17.8   1.9   4.1  ...  1.1
# 3    39     Kent Bazemore  SF   32  LAL  39  14  14.0   1.2   3.6  ...  1.4
# 4    63     Avery Bradley  SG   31  LAL  62  45  22.7   2.4   5.6  ...  1.7
# ..  ...               ...  ..  ...  ...  ..  ..   ...   ...   ...  ...  ...
# 90   93      LeBron James  PF   39  LAL   5   5  40.8  11.2  19.8  ...  6.0
# 91  162    Taurean Prince  PF   29  LAL   5   0  22.2   2.4   5.8  ...  2.2
# 92  166     Austin Reaves  SG   25  LAL   5   5  34.8   6.0  12.6  ...  2.8
# 93  174  D'Angelo Russell  PG   27  LAL   5   5  37.0   5.6  14.6  ...  2.6
# 94  195      Gabe Vincent  PG   27  LAL   5   0  13.8   0.6   2.4  ...  1.4
#
# ...
